# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv("C:\\Users\\ADMIN\\Downloads\\myexcel - myexcel.csv.csv")
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
data.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
x = data['Salary'].mean()
data['Salary'] = data['Salary'].fillna(data['Salary'].mean())
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College        Salary
# 0                Texas  7.730337e+06
# ...

# %%
data["College"] = data["College"].fillna("Unknown")
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College        Salary
# 0                Texas  7.730337e+06
# ...

# %%
data.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
data['Height'] = np.random.uniform(150, 180, size=len(data))
data.head(50)
# Out:
#                        Name                Team  Number Position  Age  \
# 0             Avery Bradley      Boston Celtics       0       PG   25
# 1               Jae Crowder      Boston Celtics      99       SF   25
# 2              John Holland      Boston Celtics      30       SG   27
# 3               R.J. Hunter      Boston Celtics      28       SG   22
# 4             Jonas Jerebko      Boston Celtics       8       PF   29
# 5              Amir Johnson      Boston Celtics      90       PF   29
# 6             Jordan Mickey      Boston Celtics      55       PF   21
# 7              Kelly Olynyk      Boston Celtics      41        C   25
# 8              Terry Rozier      Boston Celtics      12       PG   22
# 9              Marcus Smart      Boston Celtics      36       PG   22
# 10          Jared Sullinger      Boston Celtics       7        C   24
# 11            Isaiah Thomas      Boston Celtics       4       PG   27
# ...

# %%
data['Team'].value_counts()
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
data['Team'].value_counts()/len(data)*100
# Out:
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# ...

# %%
grouped = data.groupby('Position')
from IPython.display import display, HTML
for position, group in grouped:
    print(f"Group for position {position}:")
    display(HTML(group.to_html()))
    print("\n")
# Out:
# Group for position C:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Team</th>
#       <th>Number</th>
#       <th>Position</th>
#       <th>Age</th>
#       <th>Height</th>
#       <th>Weight</th>
#       <th>College</th>
#       <th>Salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7</th>
#       <td>Kelly Olynyk</td>
#       <td>Boston Celtics</td>
#       <td>41</td>
#       <td>C</td>
#       <td>25</td>
#       <td>162.156913</td>
#       <td>238</td>
#       <td>Gonzaga</td>
#       <td>2165160.0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Jared Sullinger</td>
#       <td>Boston Celtics</td>
#       <td>7</td>
#       <td>C</td>
#       <td>24</td>
#       <td>178.108405</td>
#       <td>260</td>
#       <td>Ohio State</td>
#       <td>2569260.0</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Tyler Zeller</td>
# ...

# %%
data['Age Group'] = data['Age'].apply(
    lambda age: '20-25' if 20 <= age <= 25 
    else '26-30' if 26 <= age <= 30 
    else '31-35' if 31 <= age <= 35 
    else '36 and above'
)
data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  150.304295     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  162.875351     235
# 2     John Holland  Boston Celtics      30       SG   27  153.850265     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  150.617930     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  169.106187     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  155.428209     203
# 454      Raul Neto       Utah Jazz      25       PG   24  156.154059     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  177.951492     256
# 456    Jeff Withey       Utah Jazz      24        C   26  153.027597     231
# 457       Priyanka       Utah Jazz      34        C   25  167.864730     231
#
# ...

# %%
age_group_counts = data['Age Group'].value_counts()
print("Number of employees in each age group:\n")
print(age_group_counts)
most_employees_age_group = age_group_counts.idxmax()
print("\nAge group with the most employees:", most_employees_age_group, "with", age_group_counts.max(), "employees.")
# Out:
# Number of employees in each age group:
#
# Age Group
# 20-25           198
# 26-30           167
# 31-35            68
# 36 and above     25
# Name: count, dtype: int64
#
# Age group with the most employees: 20-25 with 198 employees.

# %%
spending_salary = data.groupby(['Team','Position'])['Salary'].sum()
spending_salary.idxmax()
# Out:
# ('Los Angeles Lakers', 'SF')

# %%
correlation = data['Salary'].corr(data['Age'])
print("THE CORRELATION B/w Salary AND Age IS:",correlation)
# Out:
# THE CORRELATION B/w Salary AND Age IS: 0.2111695491768639

# %%
sns.scatterplot(x="Age" ,y= "Salary",data= data)
plt.ylabel("Salary")
plt.xlabel("Age")
plt.title("correlation b/w Salary and Age")
plt.show()

# %%
data.to_csv(r"C:\Users\ADMIN\Downloads\cleaned_dataset.csv")
